# %% [markdown]
# <a href="https://colab.research.google.com/github/vasisvaran/Deep-Learning-Papers-Reading-Roadmap/blob/master/week5/Assignment_2_Exp_2_No_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MSDS458 Research Assignment 2:
# ### Submitted by: Vasu (Vasisvaran) Gopal

# %% [markdown]
# The CIFAR-10 dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>The CIFAR-10 dataset</b><br>
# https://www.cs.toronto.edu/~kriz/cifar.html
#     </div>

# %% [markdown]
# ## Import packages needed

# %%
import datetime
import time
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as k

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.9.2

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.9.0

# %% [markdown]
# ## Set random seeds

# %%
# Set a seed value
seed_value= 42

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
tf.random.set_seed(seed_value)

# %% [markdown]
# ## Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.<br>
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# * Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
# * x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
# * y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)

# %% [markdown]
# ## Preprocess Data For Model Development

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %% [markdown]
# ## Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# ## Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# ## Rescale Examples  {Train, Validation, Test}
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255

# %% [markdown]
# 1. Each element in each example is a pixel value
# 2. Pixel values range from 0 to 255
# 3. 0 = black
# 4. 255 = white

# %%
x_train_norm = x_train_split/255
x_valid_norm = x_valid_split/255
x_test_norm = x_test/255

# %% [markdown]
# ## Flatten Examples

# %%
x_train_norm = x_train_norm.reshape(x_train_norm.shape[0], -1)
x_valid_norm = x_valid_norm.reshape(x_valid_norm.shape[0], -1)
x_test_norm = x_test_norm.reshape(x_test_norm.shape[0], -1)

# %% [markdown]
# ## Model and Performance Functions

# %%
def compile_train_model(model, x_train, y_train, x_valid, y_valid, epochs=200):
  timestamp=int(time.time())
  
  # Compile
  model.compile(optimizer='rmsprop',
                loss = 'SparseCategoricalCrossentropy',
                metrics=['accuracy'])

  # Train
  start_time = time.time()
  history = model.fit(
    x_train,
    y_train,
    epochs=epochs,
    batch_size=512,
    validation_data=(x_valid, y_valid),
    #verbose=0,
    callbacks=[    
        tf.keras.callbacks.ModelCheckpoint("DNN_model.h5",save_best_only=True,save_weights_only=False)
        ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
        ]
  )
  end_time = time.time()
  second_elapsed = round(end_time - start_time)

  print(f'Finished model training in {second_elapsed}s')

  print('Model performance with training set')
  model.evaluate(x_train, y_train)

  print('Evaluating model performance with validation set')
  model.evaluate(x_valid, y_valid)

  return history, model

# %%
def plot_history(history):
  losses = history.history['loss']
  accs = history.history['accuracy']
  val_losses = history.history['val_loss']
  val_accs = history.history['val_accuracy']
  epochs = len(losses)

  plt.figure(figsize=(16, 4))
  for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
  plt.show()

def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(16,12))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ## Build DNN Model

# %% [markdown]
# We use a Sequential class defined in Keras to create our model. We create a DNN model with 3 layers.

# %%
k.clear_session()
model = Sequential([
    Dense(input_shape = [3072], units = 1024, activation = tf.nn.sigmoid),
    Dense(units = 512, activation = tf.nn.sigmoid),
    Dense(units = 256, activation = tf.nn.sigmoid),
    Dense(name = "output_layer", units = 10, activation = tf.nn.softmax)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              3146752
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  output_layer (Dense)        (None, 10)                2570
#
# =================================================================
# Total params: 3,805,450
# Trainable params: 3,805,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# Compile and train
history, model = compile_train_model(model,
                                     x_train_norm, y_train_split,
                                     x_valid_norm, y_valid_split
                                    )
# Out:
# Epoch 1/200
# 88/88 [==============================] - 1s 8ms/step - loss: 2.2071 - accuracy: 0.1805 - val_loss: 1.9881 - val_accuracy: 0.2804
# Epoch 2/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.9984 - accuracy: 0.2751 - val_loss: 1.9723 - val_accuracy: 0.2900
# Epoch 3/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.9114 - accuracy: 0.3109 - val_loss: 1.8495 - val_accuracy: 0.3236
# Epoch 4/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.8512 - accuracy: 0.3338 - val_loss: 1.8287 - val_accuracy: 0.3400
# Epoch 5/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.8090 - accuracy: 0.3508 - val_loss: 1.8353 - val_accuracy: 0.3552
# Epoch 6/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.7646 - accuracy: 0.3661 - val_loss: 1.7360 - val_accuracy: 0.3790
# Epoch 7/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.7322 - accuracy: 0.3776 - val_loss: 1.7454 - val_accuracy: 0.3724
# Epoch 8/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.7010 - accuracy: 0.3897 - val_loss: 1.9427 - val_accuracy: 0.3188
# Epoch 9/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.6701 - accuracy: 0.4020 - val_loss: 1.7253 - val_accuracy: 0.3942
# Epoch 10/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.6455 - accuracy: 0.4107 - val_loss: 1.6159 - val_accuracy: 0.4164
# Epoch 11/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.6177 - accuracy: 0.4242 - val_loss: 1.6513 - val_accuracy: 0.4048
# Epoch 12/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.5899 - accuracy: 0.4298 - val_loss: 1.6280 - val_accuracy: 0.4146
# Epoch 13/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.5701 - accuracy: 0.4400 - val_loss: 1.5680 - val_accuracy: 0.4332
# Epoch 14/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.5532 - accuracy: 0.4443 - val_loss: 1.5944 - val_accuracy: 0.4234
# Epoch 15/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.5338 - accuracy: 0.4539 - val_loss: 1.6698 - val_accuracy: 0.4066
# Epoch 16/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.5143 - accuracy: 0.4591 - val_loss: 1.5285 - val_accuracy: 0.4572
# Epoch 17/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.4863 - accuracy: 0.4706 - val_loss: 1.6390 - val_accuracy: 0.4094
# Epoch 18/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.4813 - accuracy: 0.4693 - val_loss: 1.5770 - val_accuracy: 0.4448
# Epoch 19/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.4670 - accuracy: 0.4750 - val_loss: 1.5057 - val_accuracy: 0.4600
# Epoch 20/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.4378 - accuracy: 0.4864 - val_loss: 1.5564 - val_accuracy: 0.4326
# Epoch 21/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.4320 - accuracy: 0.4889 - val_loss: 1.5138 - val_accuracy: 0.4550
# Epoch 22/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.4078 - accuracy: 0.4990 - val_loss: 1.4780 - val_accuracy: 0.4686
# Epoch 23/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.3984 - accuracy: 0.5027 - val_loss: 1.4840 - val_accuracy: 0.4670
# Epoch 24/200
# 88/88 [==============================] - 1s 6ms/step - loss: 1.3789 - accuracy: 0.5091 - val_loss: 1.4495 - val_accuracy: 0.4758
# Epoch 25/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.3632 - accuracy: 0.5132 - val_loss: 1.4940 - val_accuracy: 0.4616
# Epoch 26/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.3469 - accuracy: 0.5180 - val_loss: 1.5094 - val_accuracy: 0.4476
# Epoch 27/200
# 88/88 [==============================] - 0s 5ms/step - loss: 1.3367 - accuracy: 0.5223 - val_loss: 1.4602 - val_accuracy: 0.4758
# Finished model training in 14s
# Model performance with training set
# 1407/1407 [==============================] - 3s 2ms/step - loss: 1.2902 - accuracy: 0.5438
# Evaluating model performance with validation set
# 157/157 [==============================] - 0s 2ms/step - loss: 1.4602 - accuracy: 0.4758
# CPU times: user 26.8 s, sys: 3.76 s, total: 30.5 s
# Wall time: 18.5 s

# %%
plt.subplots(figsize=(16,12))
plt.tight_layout()
display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)

# %% [markdown]
# ## Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= model.predict(x_test_norm)
pred1=np.argmax(pred1, axis=1)
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.49      0.64      0.55      1000
#            1       0.61      0.62      0.62      1000
#            2       0.48      0.23      0.31      1000
#            3       0.42      0.24      0.30      1000
#            4       0.36      0.60      0.45      1000
#            5       0.56      0.27      0.37      1000
#            6       0.53      0.56      0.54      1000
#            7       0.55      0.55      0.55      1000
#            8       0.51      0.72      0.60      1000
#            9       0.56      0.57      0.57      1000
#
#     accuracy                           0.50     10000
#    macro avg       0.51      0.50      0.49     10000
# weighted avg       0.51      0.50      0.49     10000
#
# Accuracy Score: 0.5003
# Root Mean Square Error: 3.0866000712758366

# %%
plot_confusion_matrix(y_test,pred1)

# %%
# Extracts the outputs of all layers:
layer_outputs = [layer.output for layer in model.layers]

# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# Get activation values for the last dense layer
activations = activation_model.predict(x_valid_norm[:3250])
dense_layer_activations = activations[-3]
output_layer_activations = activations[-1]
# Out:
# 102/102 [==============================] - 0s 1ms/step

# %% [markdown]
# ## sklearn.manifold.TSNE
# https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html

# %%
# Reduce the dimension using T-SNE to visualize i n a scatterplot
tsne = TSNE(n_components=2, verbose=1, init='pca', learning_rate='auto', perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(dense_layer_activations)

# Scaling
tsne_results = (tsne_results - tsne_results.min()) / (tsne_results.max() - tsne_results.min())
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3250 samples in 0.002s...
# [t-SNE] Computed neighbors for 3250 samples in 0.271s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3250
# [t-SNE] Computed conditional probabilities for sample 2000 / 3250
# [t-SNE] Computed conditional probabilities for sample 3000 / 3250
# [t-SNE] Computed conditional probabilities for sample 3250 / 3250
# [t-SNE] Mean sigma: 1.666961
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.251854
# [t-SNE] KL divergence after 300 iterations: 2.349246

# %%
cmap = plt.cm.tab10
plt.figure(figsize=(16,10))
scatter = plt.scatter(tsne_results[:,0],tsne_results[:,1], c=y_valid_split[:3250], s=10, cmap=cmap)
plt.legend(handles=scatter.legend_elements()[0], labels=class_names)

image_positions = np.array([[1., 1.]])
for index, position in enumerate(tsne_results):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
        image_positions = np.r_[image_positions, [position]]
        imagebox = mpl.offsetbox.AnnotationBbox(
            mpl.offsetbox.OffsetImage(x_train[index], cmap="binary"),
            position, bboxprops={"lw": 1})
        plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()
